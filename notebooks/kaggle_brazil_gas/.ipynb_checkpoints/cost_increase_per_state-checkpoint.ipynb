# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import constants as consts

# %% [markdown]
# ## Determining the Change in Cost of Gas for Brazilian Residents by State

# %% [markdown]
# In this notebook, we will determine if the cost of gas has risen for Brazilian residents after inflation has been taken into account. To determine this, we will use the previously created inflation dataframe, and also account for wage growth in Brazil.
#
# From [this](https://www.statista.com/statistics/941201/growth-rate-average-monthly-income-domestic-workers-brazil/) link, we can determine that wages from 2013 to 2019 have grown by 5.3% by adding the values above each bar in the chart. We will determine if gas prices have risen by a greater amount to determine if Brazilian workers are paying more for gas in 2019 when compared to 2013.

# %%
df = pd.read_csv('../../data/gas_prices_brazil/brazil_gas_inflation.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Last Day of Week  Year  Month  Macro Region             State  \
# 0           0       2004-05-15  2004      5  CENTRO OESTE  DISTRITO FEDERAL
# 1           1       2004-05-15  2004      5  CENTRO OESTE  DISTRITO FEDERAL
# 2           2       2004-05-15  2004      5  CENTRO OESTE  DISTRITO FEDERAL
# 3           3       2004-05-15  2004      5  CENTRO OESTE  DISTRITO FEDERAL
# 4           4       2004-05-15  2004      5  CENTRO OESTE             GOIAS
#
#     Type of Product  Mean Distribution Price  Weeks Since First Day  \
# 0  ETANOL HIDRATADO                    0.825                    1.0
# 1    GASOLINA COMUM                    1.711                    1.0
# 2               GLP                   27.165                    1.0
# 3       ÓLEO DIESEL                    1.249                    1.0
# 4  ETANOL HIDRATADO                    0.763                    1.0
#
#    Adjusted Mean Distribution Price
# 0                          0.825000
# 1                          1.711000
# 2                         27.165001
# 3                          1.249000
# 4                          0.763000

# %%
# Making a copy prevents the 'SettingWithCopyWarning' warning.

cost_df = df[(df['Last Day of Week'] == '2013-01-12') | (df['Last Day of Week'] == '2019-06-29')].copy()

# %%
cost_df.reset_index(inplace = True)

# %%
# We can drop the 'Adjusted Mean Distribution Price' column because that value reflects inflation relative to 2004.

cost_df.drop(['Adjusted Mean Distribution Price',
              'Weeks Since First Day',
              'Unnamed: 0',
              'index'], 
               axis = 1, inplace = True)

# %%
# To determine inflation from 2013 to 2019, we will use the value of 1R$ in 2019 relative to 2004 from the already
# obtained data, and divide it by the value of 1R$ in 2013 relative to 2004.

r_inf = consts.inf_rates[2019] / consts.inf_rates[2013]
r_inf
# Out:
# 1.40625

# %% [markdown]
# From this, we can conclude that inflation grew by roughly 41%, which closely resembles the calculation from [here](https://www.in2013dollars.com/brazil/inflation/2013?endYear=2019&amount=1).

# %%
cost_df
# Out:
#     Last Day of Week  Year  Month  Macro Region             State  \
# 0         2013-01-12  2013      1  CENTRO OESTE  DISTRITO FEDERAL
# 1         2013-01-12  2013      1  CENTRO OESTE  DISTRITO FEDERAL
# 2         2013-01-12  2013      1  CENTRO OESTE  DISTRITO FEDERAL
# 3         2013-01-12  2013      1  CENTRO OESTE  DISTRITO FEDERAL
# 4         2013-01-12  2013      1  CENTRO OESTE             GOIAS
# ..               ...   ...    ...           ...               ...
# 293       2019-06-29  2019      6           SUL    SANTA CATARINA
# 294       2019-06-29  2019      6           SUL    SANTA CATARINA
# 295       2019-06-29  2019      6           SUL    SANTA CATARINA
# 296       2019-06-29  2019      6           SUL    SANTA CATARINA
# 297       2019-06-29  2019      6           SUL    SANTA CATARINA
#
#       Type of Product  Mean Distribution Price
# 0    ETANOL HIDRATADO                    1.874
# 1      GASOLINA COMUM                    2.384
# 2                 GLP                   31.420
# 3         ÓLEO DIESEL                    1.954
# 4    ETANOL HIDRATADO                    1.653
# ..                ...                      ...
# 293    GASOLINA COMUM                    3.784
# 294               GLP                   51.702
# 295               GNV                    1.998
# 296       ÓLEO DIESEL                    3.023
# 297   ÓLEO DIESEL S10                    3.153
#
# [298 rows x 7 columns]

# %%
# If the year is 2013, we do not need to adjust for inflation, otherwise, adjust for inflation.

inf_adj_dist_price = []

for i in range (len(cost_df)):
    if cost_df.loc[i, 'Year'] == 2019:
        inf_adj_dist_price.append(cost_df.loc[i, 'Mean Distribution Price'] / r_inf)
    else:
        inf_adj_dist_price.append(cost_df.loc[i, 'Mean Distribution Price'])

# %%
cost_df['Adjusted Mean Distribution Price'] = inf_adj_dist_price

# %%
# Check to make sure our calculation is working as intended.

cost_df.sample(10)
# Out:
#     Last Day of Week  Year  Month  Macro Region                State  \
# 18        2013-01-12  2013      1  CENTRO OESTE   MATO GROSSO DO SUL
# 172       2019-06-29  2019      6      NORDESTE              ALAGOAS
# 2         2013-01-12  2013      1  CENTRO OESTE     DISTRITO FEDERAL
# 61        2013-01-12  2013      1      NORDESTE                PIAUI
# 22        2013-01-12  2013      1      NORDESTE              ALAGOAS
# 106       2013-01-12  2013      1         NORTE            TOCANTINS
# 146       2013-01-12  2013      1           SUL       SANTA CATARINA
# 51        2013-01-12  2013      1      NORDESTE           PERNAMBUCO
# 73        2013-01-12  2013      1      NORDESTE              SERGIPE
# 66        2013-01-12  2013      1      NORDESTE  RIO GRANDE DO NORTE
#
#       Type of Product  Mean Distribution Price  \
# 18                GLP                   39.316
# 172               GLP                   48.169
# 2                 GLP                   31.420
# 61    ÓLEO DIESEL S10                    1.945
# 22   ETANOL HIDRATADO                    2.042
# 106   ÓLEO DIESEL S10                    0.000
# 146               GNV                    1.599
# 51   ETANOL HIDRATADO                    1.913
# 73    ÓLEO DIESEL S10                    2.087
# 66        ÓLEO DIESEL                    1.899
#
#      Adjusted Mean Distribution Price
# 18                          39.316000
# 172                         34.253511
# 2                           31.420000
# 61                           1.945000
# 22                           2.042000
# 106                          0.000000
# 146                          1.599000
# 51                           1.913000
# 73                           2.087000
# 66                           1.899000

# %%
cost_df[(cost_df['Macro Region'] == 'NORDESTE') & (cost_df['State'] == 'PIAUI')]
# Out:
#     Last Day of Week  Year  Month Macro Region  State   Type of Product  \
# 57        2013-01-12  2013      1     NORDESTE  PIAUI  ETANOL HIDRATADO
# 58        2013-01-12  2013      1     NORDESTE  PIAUI    GASOLINA COMUM
# 59        2013-01-12  2013      1     NORDESTE  PIAUI               GLP
# 60        2013-01-12  2013      1     NORDESTE  PIAUI       ÓLEO DIESEL
# 61        2013-01-12  2013      1     NORDESTE  PIAUI   ÓLEO DIESEL S10
# 205       2019-06-29  2019      6     NORDESTE  PIAUI  ETANOL HIDRATADO
# 206       2019-06-29  2019      6     NORDESTE  PIAUI    GASOLINA COMUM
# 207       2019-06-29  2019      6     NORDESTE  PIAUI               GLP
# 208       2019-06-29  2019      6     NORDESTE  PIAUI       ÓLEO DIESEL
# 209       2019-06-29  2019      6     NORDESTE  PIAUI   ÓLEO DIESEL S10
#
#      Mean Distribution Price  Adjusted Mean Distribution Price
# 57                     2.141                          2.141000
# 58                     2.305                          2.305000
# 59                    33.212                         33.212000
# 60                     1.980                          1.980000
# 61                     1.945                          1.945000
# 205                    3.029                          2.153956
# 206                    4.031                          2.866489
# 207                   55.769                         39.657956
# 208                    3.222                          2.291200
# 209                    3.243                          2.306133

# %%
# Checking if there are any zeros in our cost dataframe.

cost_df[cost_df['Mean Distribution Price'] == 0]
# Out:
#     Last Day of Week  Year  Month  Macro Region                State  \
# 7         2013-01-12  2013      1  CENTRO OESTE                GOIAS
# 9         2013-01-12  2013      1  CENTRO OESTE                GOIAS
# 19        2013-01-12  2013      1  CENTRO OESTE   MATO GROSSO DO SUL
# 36        2013-01-12  2013      1      NORDESTE                CEARA
# 50        2013-01-12  2013      1      NORDESTE              PARAIBA
# 64        2013-01-12  2013      1      NORDESTE  RIO GRANDE DO NORTE
# 78        2013-01-12  2013      1         NORTE                 ACRE
# 79        2013-01-12  2013      1         NORTE                AMAPA
# 106       2013-01-12  2013      1         NORTE            TOCANTINS
# 112       2013-01-12  2013      1       SUDESTE       ESPIRITO SANTO
# 259       2019-06-29  2019      6       SUDESTE       ESPIRITO SANTO
# 265       2019-06-29  2019      6       SUDESTE         MINAS GERAIS
# 283       2019-06-29  2019      6           SUL               PARANA
#
#       Type of Product  Mean Distribution Price  \
# 7                 GNV                      0.0
# 9     ÓLEO DIESEL S10                      0.0
# 19                GNV                      0.0
# 36                GLP                      0.0
# 50    ÓLEO DIESEL S10                      0.0
# 64                GLP                      0.0
# 78    ÓLEO DIESEL S10                      0.0
# 79   ETANOL HIDRATADO                      0.0
# 106   ÓLEO DIESEL S10                      0.0
# 112   ÓLEO DIESEL S10                      0.0
# 259               GNV                      0.0
# 265               GNV                      0.0
# 283               GNV                      0.0
#
#      Adjusted Mean Distribution Price
# 7                                 0.0
# 9                                 0.0
# 19                                0.0
# 36                                0.0
# 50                                0.0
# 64                                0.0
# 78                                0.0
# 79                                0.0
# 106                               0.0
# 112                               0.0
# 259                               0.0
# 265                               0.0
# 283                               0.0

# %% [markdown]
# Because there are 13 missing values, using Excel to change these values would not take too much time, and would likely be the best way to proceed in a working environment. However, if there were significantly more zero values, replacing them with Python would be necessary, and doing so will be left to the programmer as an exercise.

# %%
cost_df[(cost_df['Macro Region'] == 'SUDESTE') & (cost_df['State'] == 'ESPIRITO SANTO')]
# Out:
#     Last Day of Week  Year  Month Macro Region           State  \
# 107       2013-01-12  2013      1      SUDESTE  ESPIRITO SANTO
# 108       2013-01-12  2013      1      SUDESTE  ESPIRITO SANTO
# 109       2013-01-12  2013      1      SUDESTE  ESPIRITO SANTO
# 110       2013-01-12  2013      1      SUDESTE  ESPIRITO SANTO
# 111       2013-01-12  2013      1      SUDESTE  ESPIRITO SANTO
# 112       2013-01-12  2013      1      SUDESTE  ESPIRITO SANTO
# 256       2019-06-29  2019      6      SUDESTE  ESPIRITO SANTO
# 257       2019-06-29  2019      6      SUDESTE  ESPIRITO SANTO
# 258       2019-06-29  2019      6      SUDESTE  ESPIRITO SANTO
# 259       2019-06-29  2019      6      SUDESTE  ESPIRITO SANTO
# 260       2019-06-29  2019      6      SUDESTE  ESPIRITO SANTO
# 261       2019-06-29  2019      6      SUDESTE  ESPIRITO SANTO
#
#       Type of Product  Mean Distribution Price  \
# 107  ETANOL HIDRATADO                    2.113
# 108    GASOLINA COMUM                    2.479
# 109               GLP                   28.394
# 110               GNV                    1.374
# 111       ÓLEO DIESEL                    1.920
# 112   ÓLEO DIESEL S10                    0.000
# 256  ETANOL HIDRATADO                    3.243
# 257    GASOLINA COMUM                    4.020
# 258               GLP                   48.437
# 259               GNV                    0.000
# 260       ÓLEO DIESEL                    3.157
# 261   ÓLEO DIESEL S10                    3.213
#
#      Adjusted Mean Distribution Price
# 107                          2.113000
# 108                          2.479000
# 109                         28.394000
# 110                          1.374000
# 111                          1.920000
# 112                          0.000000
# 256                          2.306133
# 257                          2.858667
# 258                         34.444089
# 259                          0.000000
# 260                          2.244978
# 261                          2.284800

# %%
# We need the same_cols_df for a function that will be able to replace zero values in cost_df.

same_cols_df = df.copy()
same_cols_df.drop(df.columns.difference(list(cost_df.columns)), axis = 1, inplace = True)
same_cols_df.head()
# Out:
#   Last Day of Week  Year  Month  Macro Region             State  \
# 0       2004-05-15  2004      5  CENTRO OESTE  DISTRITO FEDERAL
# 1       2004-05-15  2004      5  CENTRO OESTE  DISTRITO FEDERAL
# 2       2004-05-15  2004      5  CENTRO OESTE  DISTRITO FEDERAL
# 3       2004-05-15  2004      5  CENTRO OESTE  DISTRITO FEDERAL
# 4       2004-05-15  2004      5  CENTRO OESTE             GOIAS
#
#     Type of Product  Mean Distribution Price  Adjusted Mean Distribution Price
# 0  ETANOL HIDRATADO                    0.825                          0.825000
# 1    GASOLINA COMUM                    1.711                          1.711000
# 2               GLP                   27.165                         27.165001
# 3       ÓLEO DIESEL                    1.249                          1.249000
# 4  ETANOL HIDRATADO                    0.763                          0.763000

# %%
def cost_query_not_zero(tup):
    # The tuple that is passed to this function needs to be of the following form.
    # (Macro Region, State, Type of Product)
    return same_cols_df[
        (same_cols_df['Macro Region'] == tup[0]) & 
        (same_cols_df['State'] == tup[1]) & 
        (same_cols_df['Type of Product'] == tup[2]) &
        (same_cols_df['Mean Distribution Price'] != 0) &
        (same_cols_df['Year'] >= 2013)
    ]

# %%
# This is how we will obtain the 2013 values that need to be replaced.

cost_query_not_zero(('CENTRO OESTE', 'GOIAS', 'GNV')).iloc[0]
# Out:
# Last Day of Week                      2013-01-19
# Year                                        2013
# Month                                          1
# Macro Region                        CENTRO OESTE
# State                                      GOIAS
# Type of Product                              GNV
# Mean Distribution Price                    1.909
# Adjusted Mean Distribution Price        1.193125
# Name: 55916, dtype: object

# %%
cost_query_not_zero(('SUDESTE', 'ESPIRITO SANTO', 'GNV'))
# Out:
#        Last Day of Week  Year  Month Macro Region           State  \
# 55869        2013-01-12  2013      1      SUDESTE  ESPIRITO SANTO
# 56020        2013-01-19  2013      1      SUDESTE  ESPIRITO SANTO
# 56173        2013-01-26  2013      1      SUDESTE  ESPIRITO SANTO
# 56478        2013-02-09  2013      2      SUDESTE  ESPIRITO SANTO
# 56630        2013-02-16  2013      2      SUDESTE  ESPIRITO SANTO
# ...                 ...   ...    ...          ...             ...
# 105885       2019-05-18  2019      5      SUDESTE  ESPIRITO SANTO
# 106036       2019-05-25  2019      5      SUDESTE  ESPIRITO SANTO
# 106186       2019-06-01  2019      5      SUDESTE  ESPIRITO SANTO
# 106336       2019-06-08  2019      6      SUDESTE  ESPIRITO SANTO
# 106486       2019-06-15  2019      6      SUDESTE  ESPIRITO SANTO
#
#        Type of Product  Mean Distribution Price  \
# 55869              GNV                    1.374
# 56020              GNV                    1.600
# 56173              GNV                    1.374
# 56478              GNV                    1.225
# 56630              GNV                    1.375
# ...                ...                      ...
# 105885             GNV                    2.222
# 106036             GNV                    2.242
# 106186             GNV                    2.242
# 106336             GNV                    2.250
# 106486             GNV                    2.242
#
#         Adjusted Mean Distribution Price
# 55869                           0.858750
# 56020                           1.000000
# 56173                           0.858750
# 56478                           0.765625
# 56630                           0.859375
# ...                                  ...
# 105885                          0.987556
# 106036                          0.996444
# 106186                          0.996444
# 106336                          1.000000
# 106486                          0.996444
#
# [215 rows x 8 columns]

# %%
# This is how we will obtain the 2019 values that need to be replaced.

cost_query_not_zero(('SUDESTE', 'ESPIRITO SANTO', 'GNV')).iloc[-1]
# Out:
# Last Day of Week                        2019-06-15
# Year                                          2019
# Month                                            6
# Macro Region                               SUDESTE
# State                               ESPIRITO SANTO
# Type of Product                                GNV
# Mean Distribution Price                      2.242
# Adjusted Mean Distribution Price          0.996444
# Name: 106486, dtype: object

# %%
list(cost_df[cost_df['Mean Distribution Price'] == 0].index)
# Out:
# [7, 9, 19, 36, 50, 64, 78, 79, 106, 112, 259, 265, 283]

# %%
cost_df.iloc[7]
# Out:
# Last Day of Week                      2013-01-12
# Year                                        2013
# Month                                          1
# Macro Region                        CENTRO OESTE
# State                                      GOIAS
# Type of Product                              GNV
# Mean Distribution Price                      0.0
# Adjusted Mean Distribution Price             0.0
# Name: 7, dtype: object

# %%
cost_df.iloc[7]['Year']
# Out:
# 2013

# %%
cost_query_not_zero(('CENTRO OESTE', 'GOIAS', 'GNV')).iloc[0]
# Out:
# Last Day of Week                      2013-01-19
# Year                                        2013
# Month                                          1
# Macro Region                        CENTRO OESTE
# State                                      GOIAS
# Type of Product                              GNV
# Mean Distribution Price                    1.909
# Adjusted Mean Distribution Price        1.193125
# Name: 55916, dtype: object

# %%
# Iterate over the indicies with zero values, and replace the values appropriately.

for ind in list(cost_df[cost_df['Mean Distribution Price'] == 0].index):
    if cost_df.iloc[ind]['Year'] == 2013:
        cost_df.iloc[ind] = cost_query_not_zero((cost_df.iloc[ind]['Macro Region'], cost_df.iloc[ind]['State'], cost_df.iloc[ind]['Type of Product'])).iloc[0]
    else:
        cost_df.iloc[ind] = cost_query_not_zero((cost_df.iloc[ind]['Macro Region'], cost_df.iloc[ind]['State'], cost_df.iloc[ind]['Type of Product'])).iloc[-1]

# %%
cost_df
# Out:
#     Last Day of Week  Year  Month  Macro Region             State  \
# 0         2013-01-12  2013      1  CENTRO OESTE  DISTRITO FEDERAL
# 1         2013-01-12  2013      1  CENTRO OESTE  DISTRITO FEDERAL
# 2         2013-01-12  2013      1  CENTRO OESTE  DISTRITO FEDERAL
# 3         2013-01-12  2013      1  CENTRO OESTE  DISTRITO FEDERAL
# 4         2013-01-12  2013      1  CENTRO OESTE             GOIAS
# ..               ...   ...    ...           ...               ...
# 293       2019-06-29  2019      6           SUL    SANTA CATARINA
# 294       2019-06-29  2019      6           SUL    SANTA CATARINA
# 295       2019-06-29  2019      6           SUL    SANTA CATARINA
# 296       2019-06-29  2019      6           SUL    SANTA CATARINA
# 297       2019-06-29  2019      6           SUL    SANTA CATARINA
#
#       Type of Product  Mean Distribution Price  \
# 0    ETANOL HIDRATADO                    1.874
# 1      GASOLINA COMUM                    2.384
# 2                 GLP                   31.420
# 3         ÓLEO DIESEL                    1.954
# 4    ETANOL HIDRATADO                    1.653
# ..                ...                      ...
# 293    GASOLINA COMUM                    3.784
# 294               GLP                   51.702
# 295               GNV                    1.998
# 296       ÓLEO DIESEL                    3.023
# 297   ÓLEO DIESEL S10                    3.153
#
#      Adjusted Mean Distribution Price
# 0                            1.874000
# 1                            2.384000
# 2                           31.420000
# 3                            1.954000
# 4                            1.653000
# ..                                ...
# 293                          2.690844
# 294                         36.765867
# 295                          1.420800
# 296                          2.149689
# 297                          2.242133
#
# [298 rows x 8 columns]

# %%
# Checking that the replacement worked as intended

for i in [7, 9, 19, 36, 50, 64, 78, 79, 106, 112, 259, 265, 283]:
    print (cost_df.iloc[i], '\n')
# Out:
# Last Day of Week                      2013-01-19
# Year                                        2013
# Month                                          1
# Macro Region                        CENTRO OESTE
# State                                      GOIAS
# Type of Product                              GNV
# Mean Distribution Price                    1.909
# Adjusted Mean Distribution Price        1.193125
# Name: 7, dtype: object
#
# Last Day of Week                         2013-01-19
# Year                                           2013
# Month                                             1
# Macro Region                           CENTRO OESTE
# State                                         GOIAS
# Type of Product                     ÓLEO DIESEL S10
# Mean Distribution Price                       2.058
# Adjusted Mean Distribution Price            1.28625
# Name: 9, dtype: object
#
# Last Day of Week                            2013-03-02
# Year                                              2013
# Month                                                2
# Macro Region                              CENTRO OESTE
# State                               MATO GROSSO DO SUL
# Type of Product                                    GNV
# Mean Distribution Price                           1.42
# Adjusted Mean Distribution Price                0.8875
# Name: 19, dtype: object
#
# Last Day of Week                    2015-12-05
# Year                                      2015
# Month                                       11
# Macro Region                          NORDESTE
# State                                    CEARA
# Type of Product                            GLP
# Mean Distribution Price                   46.0
# Adjusted Mean Distribution Price     24.731183
# Name: 36, dtype: object
#
# Last Day of Week                         2013-01-19
# Year                                           2013
# Month                                             1
# Macro Region                               NORDESTE
# State                                       PARAIBA
# Type of Product                     ÓLEO DIESEL S10
# Mean Distribution Price                       1.958
# Adjusted Mean Distribution Price            1.22375
# Name: 50, dtype: object
#
# Last Day of Week                             2013-06-08
# Year                                               2013
# Month                                                 6
# Macro Region                                   NORDESTE
# State                               RIO GRANDE DO NORTE
# Type of Product                                     GLP
# Mean Distribution Price                            31.5
# Adjusted Mean Distribution Price                19.6875
# Name: 64, dtype: object
#
# Last Day of Week                         2013-01-26
# Year                                           2013
# Month                                             1
# Macro Region                                  NORTE
# State                                          ACRE
# Type of Product                     ÓLEO DIESEL S10
# Mean Distribution Price                       2.284
# Adjusted Mean Distribution Price             1.4275
# Name: 78, dtype: object
#
# Last Day of Week                          2013-01-26
# Year                                            2013
# Month                                              1
# Macro Region                                   NORTE
# State                                          AMAPA
# Type of Product                     ETANOL HIDRATADO
# Mean Distribution Price                        1.973
# Adjusted Mean Distribution Price            1.233125
# Name: 79, dtype: object
#
# Last Day of Week                         2013-02-09
# Year                                           2013
# Month                                             2
# Macro Region                                  NORTE
# State                                     TOCANTINS
# Type of Product                     ÓLEO DIESEL S10
# Mean Distribution Price                       1.998
# Adjusted Mean Distribution Price            1.24875
# Name: 106, dtype: object
#
# Last Day of Week                         2013-01-19
# Year                                           2013
# Month                                             1
# Macro Region                                SUDESTE
# State                                ESPIRITO SANTO
# Type of Product                     ÓLEO DIESEL S10
# Mean Distribution Price                       1.929
# Adjusted Mean Distribution Price           1.205625
# Name: 112, dtype: object
#
# Last Day of Week                        2019-06-15
# Year                                          2019
# Month                                            6
# Macro Region                               SUDESTE
# State                               ESPIRITO SANTO
# Type of Product                                GNV
# Mean Distribution Price                      2.242
# Adjusted Mean Distribution Price          0.996444
# Name: 259, dtype: object
#
# Last Day of Week                      2019-05-04
# Year                                        2019
# Month                                          4
# Macro Region                             SUDESTE
# State                               MINAS GERAIS
# Type of Product                              GNV
# Mean Distribution Price                    2.822
# Adjusted Mean Distribution Price        1.254222
# Name: 265, dtype: object
#
# Last Day of Week                    2019-02-16
# Year                                      2019
# Month                                        2
# Macro Region                               SUL
# State                                   PARANA
# Type of Product                            GNV
# Mean Distribution Price                  1.909
# Adjusted Mean Distribution Price      0.848444
# Name: 283, dtype: object
