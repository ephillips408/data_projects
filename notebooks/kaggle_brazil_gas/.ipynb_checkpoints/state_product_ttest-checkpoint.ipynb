# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import shapiro
from scipy.stats import ttest_rel

import constants as consts

# %%
df = pd.read_csv('../../data/gas_prices_brazil/brazil_gas_inflation.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Last Day of Week  Year  Month  Macro Region             State  \
# 0           0       2004-05-15  2004      5  CENTRO OESTE  DISTRITO FEDERAL
# 1           1       2004-05-15  2004      5  CENTRO OESTE  DISTRITO FEDERAL
# 2           2       2004-05-15  2004      5  CENTRO OESTE  DISTRITO FEDERAL
# 3           3       2004-05-15  2004      5  CENTRO OESTE  DISTRITO FEDERAL
# 4           4       2004-05-15  2004      5  CENTRO OESTE             GOIAS
#
#     Type of Product Percent of Total Population in 2020  \
# 0  ETANOL HIDRATADO                                1.4%
# 1    GASOLINA COMUM                                1.4%
# 2               GLP                                1.4%
# 3       ÓLEO DIESEL                                1.4%
# 4  ETANOL HIDRATADO                                3.4%
#
#    Mean Distribution Price  Weeks Since First Day  \
# 0                    0.825                    1.0
# 1                    1.711                    1.0
# 2                   27.165                    1.0
# 3                    1.249                    1.0
# 4                    0.763                    1.0
#
#    Adjusted Mean Distribution Price
# 0                          0.825000
# 1                          1.711000
# 2                         27.165001
# 3                          1.249000
# 4                          0.763000

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
# Need to convert 'Percent of Total Population in 2020' to float.
# Remove percent sign, then float(entry)

for ind in range(len(df)):
    df.at[ind, 'Percent of Total Population in 2020'] = float(df.at[ind, 'Percent of Total Population in 2020'][0:-1])

# %%
# Defining high population as having at least 4% of the population in 2020 was arbitrarily chosen.

high_pop_df = df[df['Percent of Total Population in 2020'] >= 4.0]
low_pop_df = df[df['Percent of Total Population in 2020'] < 4.0]

# %%
high_pop_df.sample(10)
# Out:
#       Last Day of Week  Year  Month Macro Region           State  \
# 72561       2015-02-21  2015      2     NORDESTE           BAHIA
# 33389       2009-07-18  2009      7      SUDESTE       SAO PAULO
# 96968       2018-03-31  2018      3     NORDESTE      PERNAMBUCO
# 60531       2013-08-17  2013      8     NORDESTE      PERNAMBUCO
# 22950       2007-12-08  2007     12          SUL          PARANA
# 55389       2012-12-22  2012     12     NORDESTE           BAHIA
# 29894       2009-01-03  2008     12      SUDESTE  RIO DE JANEIRO
# 98248       2018-05-26  2018      5      SUDESTE       SAO PAULO
# 79956       2016-01-30  2016      1      SUDESTE  RIO DE JANEIRO
# 5914        2005-04-09  2005      4      SUDESTE    MINAS GERAIS
#
#         Type of Product Percent of Total Population in 2020  \
# 72561   ÓLEO DIESEL S10                                 7.1
# 33389       ÓLEO DIESEL                                21.9
# 96968   ÓLEO DIESEL S10                                 4.5
# 60531               GNV                                 4.5
# 22950    GASOLINA COMUM                                 5.4
# 55389    GASOLINA COMUM                                 7.1
# 29894               GLP                                 8.2
# 98248    GASOLINA COMUM                                21.9
# 79956  ETANOL HIDRATADO                                 8.2
# 5914                GNV                                10.1
#
#        Mean Distribution Price  Weeks Since First Day  \
# 72561                    2.593                  563.0
# 33389                    1.721                  271.0
# 96968                    2.965                  725.0
# 60531                    1.144                  484.0
# 22950                    2.130                  187.0
# 55389                    2.362                  450.0
# 29894                   25.507                  243.0
# 98248                    3.793                  733.0
# 79956                    2.910                  612.0
# 5914                     0.833                   48.0
#
#        Adjusted Mean Distribution Price
# 72561                          1.394086
# 33389                          1.344531
# 96968                          1.372685
# 60531                          0.715000
# 22950                          1.852174
# 55389                          1.564238
# 29894                         20.907377
# 98248                          1.756019
# 79956                          1.440594
# 5914                           0.778505

# %%
low_pop_df.sample(10)
# Out:
#        Last Day of Week  Year  Month  Macro Region                State  \
# 88813        2017-03-18  2017      3      NORDESTE             MARANHAO
# 100323       2018-09-01  2018      8         NORTE              RORAIMA
# 63152        2013-12-14  2013     12         NORTE                AMAPA
# 42202        2010-12-11  2010     12         NORTE                 ACRE
# 60997        2013-09-07  2013      9      NORDESTE  RIO GRANDE DO NORTE
# 16737        2006-12-23  2006     12           SUL       SANTA CATARINA
# 62563        2013-11-16  2013     11         NORTE              RORAIMA
# 22228        2007-11-03  2007     10  CENTRO OESTE          MATO GROSSO
# 37341        2010-03-13  2010      3         NORTE             AMAZONAS
# 28555        2008-10-25  2008     10  CENTRO OESTE     DISTRITO FEDERAL
#
#          Type of Product Percent of Total Population in 2020  \
# 88813    ÓLEO DIESEL S10                                 3.4
# 100323       ÓLEO DIESEL                                 0.3
# 63152        ÓLEO DIESEL                                 0.4
# 42202     GASOLINA COMUM                                 0.4
# 60997   ETANOL HIDRATADO                                 1.7
# 16737                GLP                                 3.4
# 62563        ÓLEO DIESEL                                 0.3
# 22228                GLP                                 1.7
# 37341        ÓLEO DIESEL                                 2.0
# 28555     GASOLINA COMUM                                 1.4
#
#         Mean Distribution Price  Weeks Since First Day  \
# 88813                     2.876                  671.0
# 100323                    3.091                  747.0
# 63152                     2.183                  501.0
# 42202                     2.535                  344.0
# 60997                     2.195                  487.0
# 16737                    27.503                  137.0
# 62563                     2.164                  497.0
# 22228                    34.738                  182.0
# 37341                     1.901                  305.0
# 28555                     2.154                  233.0
#
#         Adjusted Mean Distribution Price
# 88813                           1.376077
# 100323                          1.431019
# 63152                           1.364375
# 42202                           1.891791
# 60997                           1.371875
# 16737                          24.777478
# 62563                           1.352500
# 22228                          30.206956
# 37341                           1.418657
# 28555                           1.765574

# %%
high_pop_df['Year']
# Out:
# 22        2004
# 23        2004
# 24        2004
# 25        2004
# 26        2004
#           ...
# 106812    2019
# 106813    2019
# 106814    2019
# 106815    2019
# 106816    2019
# Name: Year, Length: 37586, dtype: int64

# %%
def state_prod_query(df, state, prod_type):
    
    # Requires that the dataframe passed has columns named 'State' and 'Type of Product'
    
    return df[
        (df['State'] == state) &
        (df['Type of Product'] == prod_type) &
        (df['Adjusted Mean Distribution Price'] != 0)
    ]

# %%
# Creating a list of the information needed and then creating a dataframe from the list is the preferred way
# to create the necessary dataframe.

# See the link below for more information.
# https://stackoverflow.com/questions/13784192/creating-an-empty-pandas-dataframe-then-filling-it

# The 'Before Year' and 'After Year' columns make sure that inflation is properly adjusted.

def ttest_prep(df, num_col, state_list, prod_type):
    
    # num_col is short for numerical column.
    # state_list and prod_type can be altered as necessary.
    
    state_before_after = []
    
    for state in state_list:
        state_before_after.append([
            state,
            state_prod_query(df, state, prod_type).iloc[0]['Year'], # Remove this line for improved reusability.
            state_prod_query(df, state, prod_type).iloc[-1]['Year'], # Remove this line for improved reusability.
            state_prod_query(df, state, prod_type).iloc[0][num_col],
            state_prod_query(df, state, prod_type).iloc[-1][num_col],
        ])
        
    ttest_df = pd.DataFrame(state_before_after, columns = ['State', 'Before Year', 'After Year', 'Before', 'After'])
    ttest_df['Difference'] = ttest_df['After'] - ttest_df['Before']
    
    return ttest_df

# %%
high_gc_ttest = ttest_prep(
    high_pop_df, 
    'Adjusted Mean Distribution Price', 
    list(high_pop_df['State'].unique()), 
    'GASOLINA COMUM'
)

low_gc_ttest = ttest_prep(
    low_pop_df, 
    'Adjusted Mean Distribution Price', 
    list(low_pop_df['State'].unique()), 
    'GASOLINA COMUM'
)

# %%
# View of the dataframes for reference.

high_gc_ttest
# Out:
#                State  Before Year  After Year  Before     After  Difference
# 0              BAHIA         2004        2019   1.730  1.753778    0.023778
# 1              CEARA         2004        2019   1.804  1.793333   -0.010667
# 2         PERNAMBUCO         2004        2019   1.726  1.753333    0.027333
# 3               PARA         2004        2019   1.935  1.800000   -0.135000
# 4       MINAS GERAIS         2004        2019   1.698  1.899556    0.201556
# 5     RIO DE JANEIRO         2004        2019   1.791  1.951111    0.160111
# 6          SAO PAULO         2004        2019   1.656  1.650222   -0.005778
# 7             PARANA         2004        2019   1.728  1.706222   -0.021778
# 8  RIO GRANDE DO SUL         2004        2019   1.793  1.826222    0.033222

# %%
low_gc_ttest
# Out:
#                   State  Before Year  After Year  Before     After  Difference
# 0      DISTRITO FEDERAL         2004        2019   1.711  1.746222    0.035222
# 1                 GOIAS         2004        2019   1.729  1.813778    0.084778
# 2           MATO GROSSO         2004        2019   1.886  1.740000   -0.146000
# 3    MATO GROSSO DO SUL         2004        2019   1.795  1.703111   -0.091889
# 4               ALAGOAS         2004        2019   1.740  1.789333    0.049333
# 5              MARANHAO         2004        2019   1.739  1.723556   -0.015444
# 6               PARAIBA         2004        2019   1.667  1.768444    0.101444
# 7                 PIAUI         2004        2019   1.739  1.791556    0.052556
# 8   RIO GRANDE DO NORTE         2004        2019   1.715  1.775556    0.060555
# 9               SERGIPE         2004        2019   1.734  1.801778    0.067778
# 10                 ACRE         2004        2019   1.843  1.865778    0.022778
# 11                AMAPA         2004        2019   1.885  1.617778   -0.267222
# 12             AMAZONAS         2004        2019   1.706  1.648000   -0.058000
# 13             RONDONIA         2004        2019   1.806  1.767556   -0.038444
# 14              RORAIMA         2004        2019   1.651  1.649778   -0.001222
# 15            TOCANTINS         2004        2019   1.724  1.795556    0.071556
# 16       ESPIRITO SANTO         2004        2019   1.739  1.786667    0.047667
# 17       SANTA CATARINA         2004        2019   1.718  1.681778   -0.036222

# %%
print (shapiro(high_gc_ttest['Difference']))
print (shapiro(low_gc_ttest['Difference']))
# Out:
# ShapiroResult(statistic=0.9126634001731873, pvalue=0.33496448397636414)
# ShapiroResult(statistic=0.8634587526321411, pvalue=0.013907150365412235)

# %%
ttest_rel(high_gc_ttest['After'],
          high_gc_ttest['Before'])
# Out:
# Ttest_relResult(statistic=0.913521700220647, pvalue=0.3876707172350812)

# %%
# prod_type_dict = {}

# for prod in list(df['Type of Product'].unique()):
#     prod_type_dict[prod] = {
#         'High Population': ttest_prep(high_pop_df, 
#                                       'Adjusted Mean Distribution Price',
#                                       list(high_pop_df['State'].unique()),
#                                       prod),

#         'Low Population': ttest_prep(low_pop_df, 
#                                      'Adjusted Mean Distribution Price',
#                                      list(high_pop_df['State'].unique()),
#                                      prod)
                
#     }

# %%
print (list(low_pop_df['Type of Product'].unique()))
print (list(high_pop_df['Type of Product'].unique()))
# Out:
# ['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'ÓLEO DIESEL', 'GNV', 'ÓLEO DIESEL S10']
# ['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL', 'ÓLEO DIESEL S10']

# %%
# GNV may have too many missing values to determine an accurate conclusion.
# GNV is also what is raising an IndexError in In[16]

ttest_prep(low_pop_df, 
           'Adjusted Mean Distribution Price',
           list(low_pop_df['State'].unique()),
           'GNV'
          )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-30b867a29b2a> in <module>
#       2 # GNV is also what is raising an IndexError in In[16]
#       3
# ----> 4 ttest_prep(low_pop_df,
#       5            'Adjusted Mean Distribution Price',
#       6            list(low_pop_df['State'].unique()),
#
# <ipython-input-11-5e40c09e92d0> in ttest_prep(df, num_col, state_list, prod_type)
#      15         state_before_after.append([
#      16             state,
# ---> 17             state_prod_query(df, state, prod_type).iloc[0]['Year'], # Remove this line for improved reusability.
#      18             state_prod_query(df, state, prod_type).iloc[-1]['Year'], # Remove this line for improved reusability.
#      19             state_prod_query(df, state, prod_type).iloc[0][num_col],
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds
