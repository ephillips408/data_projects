# %%
import numpy as np
import pandas as pd

import constants as consts

# %%
# Allows for .py files to automatically reload.
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Inflation Cleaning
#
# In this notebook, we will create a dataframe that will be used to show the price of the various types of gasoline after they are adjusted for inflation. Inflation data was gathered [here](https://www.in2013dollars.com/brazil/inflation/2004?endYear=2019&amount=1), and reflects inflation relative to 2004.

# %%
df = pd.read_csv('../../data/gas_prices_brazil/brazil_gas_cleaned.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 First Day of Week Last Day of Week  Macro Region  \
# 0           0        2004-05-09       2004-05-15  CENTRO OESTE
# 1           1        2004-05-16       2004-05-22  CENTRO OESTE
# 2           2        2004-05-23       2004-05-29  CENTRO OESTE
# 3           3        2004-05-30       2004-06-05  CENTRO OESTE
# 4           4        2004-06-06       2004-06-12  CENTRO OESTE
#
#               State   Type of Product  Number of Stations Unit of Measurement  \
# 0  DISTRITO FEDERAL  ETANOL HIDRATADO                 127                R$/l
# 1  DISTRITO FEDERAL  ETANOL HIDRATADO                 144                R$/l
# 2  DISTRITO FEDERAL  ETANOL HIDRATADO                 129                R$/l
# 3  DISTRITO FEDERAL  ETANOL HIDRATADO                 144                R$/l
# 4  DISTRITO FEDERAL  ETANOL HIDRATADO                 129                R$/l
#
#    Mean Market Value  Std Dev  ...  Mean Distribution Price  \
# 0              1.288    0.016  ...                    0.825
# 1              1.271    0.039  ...                    0.823
# 2              1.282    0.024  ...                    0.818
# 3              1.373    0.051  ...                    0.894
# 4              1.373    0.059  ...                    0.951
#
#    Distribution Standard Deviation Distribution Min Price  \
# 0                             0.11                 0.4201
# 1                            0.111                 0.4094
# 2                            0.137                 0.3879
# 3                            0.147                 0.4094
# 4                            0.125                 0.5169
#
#    Distribution Max Price Distribution Variation Coefficient Month  Year  \
# 0                  0.9666                              0.133     5  2004
# 1                  1.1931                              0.135     5  2004
# 2                  1.0336                              0.167     5  2004
# 3                  1.4206                              0.164     5  2004
# 4                   1.115                              0.131     6  2004
#
#   Weeks Since First Day Percent of Total Population in 2020  Population
# 0                     1                                1.4%     2051146
# 1                     2                                1.4%     2051146
# 2                     3                                1.4%     2051146
# 3                     4                                1.4%     2051146
# 4                     5                                1.4%     2051146
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Unnamed: 0                           106823 non-null  int64
#  1   First Day of Week                    106823 non-null  object
#  2   Last Day of Week                     106823 non-null  object
#  3   Macro Region                         106823 non-null  object
#  4   State                                106823 non-null  object
#  5   Type of Product                      106823 non-null  object
#  6   Number of Stations                   106823 non-null  int64
#  7   Unit of Measurement                  106823 non-null  object
#  8   Mean Market Value                    106823 non-null  float64
#  9   Std Dev                              106823 non-null  float64
#  10  Min Price Observed                   106823 non-null  float64
#  11  Max Price Observed                   106823 non-null  float64
#  12  Mean Price Margin                    106823 non-null  object
#  13  Variation Coefficient                106823 non-null  float64
#  14  Mean Distribution Price              106823 non-null  object
#  15  Distribution Standard Deviation      106823 non-null  object
#  16  Distribution Min Price               106823 non-null  object
#  17  Distribution Max Price               106823 non-null  object
#  18  Distribution Variation Coefficient   106823 non-null  object
#  19  Month                                106823 non-null  int64
#  20  Year                                 106823 non-null  int64
#  21  Weeks Since First Day                106823 non-null  int64
#  22  Percent of Total Population in 2020  106823 non-null  object
#  23  Population                           106823 non-null  int64
# dtypes: float64(5), int64(6), object(13)
# memory usage: 19.6+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'First Day of Week', 'Last Day of Week', 'Macro Region',
#        'State', 'Type of Product', 'Number of Stations', 'Unit of Measurement',
#        'Mean Market Value', 'Std Dev', 'Min Price Observed',
#        'Max Price Observed', 'Mean Price Margin', 'Variation Coefficient',
#        'Mean Distribution Price', 'Distribution Standard Deviation',
#        'Distribution Min Price', 'Distribution Max Price',
#        'Distribution Variation Coefficient', 'Month', 'Year',
#        'Weeks Since First Day', 'Percent of Total Population in 2020',
#        'Population'],
#       dtype='object')

# %%
# Keeps all of the columns in the list.

df.drop(df.columns.difference([
    'Last Day of Week', 'Macro Region', 'State', 'Type of Product', 'Mean Distribution Price', 'Month', 'Year', 'Weeks Since First Day', 'Percent of Total Population in 2020'
]), axis = 1, inplace = True)

# %%
df.head()
# Out:
#   Last Day of Week  Macro Region             State   Type of Product  \
# 0       2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1       2004-05-22  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 2       2004-05-29  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 3       2004-06-05  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 4       2004-06-12  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
#
#   Mean Distribution Price  Month  Year  Weeks Since First Day  \
# 0                   0.825      5  2004                      1
# 1                   0.823      5  2004                      2
# 2                   0.818      5  2004                      3
# 3                   0.894      5  2004                      4
# 4                   0.951      6  2004                      5
#
#   Percent of Total Population in 2020
# 0                                1.4%
# 1                                1.4%
# 2                                1.4%
# 3                                1.4%
# 4                                1.4%

# %%
consts.inf_rates[2005]
# Out:
# 1.07

# %%
df['Year'].map(type).value_counts()
# Out:
# <class 'int'>    106823
# Name: Year, dtype: int64

# %%
df['Mean Distribution Price'].map(type).value_counts()
# Out:
# <class 'str'>    106823
# Name: Mean Distribution Price, dtype: int64

# %% [markdown]
# Because the Mean Distribution Price column is represented as a string, we will need to convert this column to a float in order to perform the necessary calculations.

# %%
df[df['Mean Distribution Price'] == '-']
# Out:
#        Last Day of Week  Macro Region             State   Type of Product  \
# 291          2010-01-09  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 292          2010-01-16  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 294          2010-01-30  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 305          2010-04-17  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 306          2010-04-24  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# ...                 ...           ...               ...               ...
# 106612       2018-10-27           SUL    SANTA CATARINA               GNV
# 106636       2018-11-24           SUL    SANTA CATARINA               GNV
# 106642       2018-12-01           SUL    SANTA CATARINA               GNV
# 106660       2018-12-22           SUL    SANTA CATARINA               GNV
# 106666       2018-12-29           SUL    SANTA CATARINA               GNV
#
#        Mean Distribution Price  Month  Year  Weeks Since First Day  \
# 291                          -      1  2010                    296
# 292                          -      1  2010                    297
# 294                          -      1  2010                    299
# 305                          -      4  2010                    310
# 306                          -      4  2010                    311
# ...                        ...    ...   ...                    ...
# 106612                       -     10  2018                    755
# 106636                       -     11  2018                    759
# 106642                       -     11  2018                    760
# 106660                       -     12  2018                    763
# 106666                       -     12  2018                    764
#
#        Percent of Total Population in 2020
# 291                                   1.4%
# 292                                   1.4%
# 294                                   1.4%
# 305                                   1.4%
# 306                                   1.4%
# ...                                    ...
# 106612                                3.4%
# 106636                                3.4%
# 106642                                3.4%
# 106660                                3.4%
# 106666                                3.4%
#
# [3400 rows x 9 columns]

# %%
# Converting the values in the 'Mean Distribution Price' column to floats.

df['Mean Distribution Price'] = df['Mean Distribution Price'].str.replace('-', '0').fillna(0).astype(float)
df['Mean Distribution Price'] = pd.to_numeric(df['Mean Distribution Price'], downcast = 'float')
df['Mean Distribution Price'].map(type).value_counts()
# Out:
# <class 'float'>    106823
# Name: Mean Distribution Price, dtype: int64

# %%
inf_adj_dist_price = []

for i in range (len(df)):
    inf_adj_dist_price.append(df.loc[i, 'Mean Distribution Price'] / consts.inf_rates[df.loc[i, 'Year']])

# %%
df['Adjusted Mean Distribution Price'] = inf_adj_dist_price

# %%
# Making sure that the replaced values match the dataframe prior to the type conversion.

df[df['Mean Distribution Price'] == 0]
# Out:
#        Last Day of Week  Macro Region             State   Type of Product  \
# 291          2010-01-09  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 292          2010-01-16  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 294          2010-01-30  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 305          2010-04-17  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 306          2010-04-24  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# ...                 ...           ...               ...               ...
# 106612       2018-10-27           SUL    SANTA CATARINA               GNV
# 106636       2018-11-24           SUL    SANTA CATARINA               GNV
# 106642       2018-12-01           SUL    SANTA CATARINA               GNV
# 106660       2018-12-22           SUL    SANTA CATARINA               GNV
# 106666       2018-12-29           SUL    SANTA CATARINA               GNV
#
#         Mean Distribution Price  Month  Year  Weeks Since First Day  \
# 291                         0.0      1  2010                    296
# 292                         0.0      1  2010                    297
# 294                         0.0      1  2010                    299
# 305                         0.0      4  2010                    310
# 306                         0.0      4  2010                    311
# ...                         ...    ...   ...                    ...
# 106612                      0.0     10  2018                    755
# 106636                      0.0     11  2018                    759
# 106642                      0.0     11  2018                    760
# 106660                      0.0     12  2018                    763
# 106666                      0.0     12  2018                    764
#
#        Percent of Total Population in 2020  Adjusted Mean Distribution Price
# 291                                   1.4%                               0.0
# 292                                   1.4%                               0.0
# 294                                   1.4%                               0.0
# 305                                   1.4%                               0.0
# 306                                   1.4%                               0.0
# ...                                    ...                               ...
# 106612                                3.4%                               0.0
# 106636                                3.4%                               0.0
# 106642                                3.4%                               0.0
# 106660                                3.4%                               0.0
# 106666                                3.4%                               0.0
#
# [3400 rows x 10 columns]

# %%
# Checking which product types have the most missing values.

df[df['Mean Distribution Price'] == 0].groupby(['Month', 'Year', 'Type of Product']).count().reset_index()['Type of Product'].value_counts()
# Out:
# GNV                 173
# ETANOL HIDRATADO     85
# GLP                  83
# ÓLEO DIESEL S10      40
# ÓLEO DIESEL          14
# GASOLINA COMUM       11
# Name: Type of Product, dtype: int64

# %% [markdown]
# ## Addressing the Issue of Replacing NA Values with Zero
#
# Because we have replaced missing values with zero, the price of each product may be calculated to be lower than its true value when accounting for inflation. Given the value counts in the cell above, we can determine which product types will show the most inaccuracies between the calculated value and the true value.

# %%
zero_adj_df = df.groupby(['Last Day of Week', 'Year', 'Month', 'Macro Region', 'State', 'Type of Product', 'Percent of Total Population in 2020']).mean().reset_index()

# %%
# Randomly select ten rows to check that our calculation is working as intended.

zero_adj_df.sample(10)
# Out:
#       Last Day of Week  Year  Month  Macro Region           State  \
# 73848       2015-04-18  2015      4         NORTE         RORAIMA
# 1217        2004-07-17  2004      7           SUL          PARANA
# 29306       2008-12-06  2008     11  CENTRO OESTE     MATO GROSSO
# 78164       2015-11-07  2015     11           SUL  SANTA CATARINA
# 14096       2006-07-29  2006      7       SUDESTE  RIO DE JANEIRO
# 95089       2017-12-30  2017     12           SUL  SANTA CATARINA
# 72735       2015-02-28  2015      2      NORDESTE      PERNAMBUCO
# 99897       2018-08-11  2018      8       SUDESTE  RIO DE JANEIRO
# 72066       2015-01-24  2015      1           SUL  SANTA CATARINA
# 76063       2015-08-01  2015      7      NORDESTE         ALAGOAS
#
#         Type of Product Percent of Total Population in 2020  \
# 73848  ETANOL HIDRATADO                                0.3%
# 1217                GLP                                5.4%
# 29306               GLP                                1.7%
# 78164               GLP                                3.4%
# 14096               GLP                                8.2%
# 95089  ETANOL HIDRATADO                                3.4%
# 72735               GNV                                4.5%
# 99897       ÓLEO DIESEL                                8.2%
# 72066               GNV                                3.4%
# 76063               GNV                                1.6%
#
#        Mean Distribution Price  Weeks Since First Day  \
# 73848                 2.577000                  571.0
# 1217                 25.823999                   10.0
# 29306                34.592999                  239.0
# 78164                43.000000                  600.0
# 14096                26.384001                  116.0
# 95089                 3.142000                  712.0
# 72735                 1.422000                  564.0
# 99897                 3.030000                  744.0
# 72066                 1.600000                  559.0
# 76063                 1.430000                  586.0
#
#        Adjusted Mean Distribution Price
# 73848                          1.385484
# 1217                          25.823999
# 29306                         28.354917
# 78164                         23.118280
# 14096                         23.769370
# 95089                          1.503349
# 72735                          0.764516
# 99897                          1.402778
# 72066                          0.860215
# 76063                          0.768817

# %%
# zero_adj_df.to_csv(path_or_buf = '../../data/gas_prices_brazil/brazil_gas_inflation.csv')

# %% [markdown]
# ## Note About Tableau Visualization Using this Table
#
# Because 0 values were creating troubles while showing the 'Adjusted Mean Distribution Price' over time, the following calculated field was created in Tableau to better visualize the data.
#
# IF [Adjusted Mean Distribution Price] =! 0 THEN [Adjusted Mean Distribution Price]
# ELSE NULL
# END
